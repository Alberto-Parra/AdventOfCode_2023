# %%
import pandas as pd

# %%
df=pd.DataFrame()
df=pd.read_csv('puzzle_input.csv',sep=';',header=None)
df
# Out:
#            0                         1                          2  \
# 0     Game 1                    1 blue            4 green, 5 blue
# 1     Game 2          17 red, 10 green    3 blue, 17 red, 7 green
# 2     Game 3   10 blue, 3 green, 8 red   15 green, 14 blue, 1 red
# 3     Game 4             1 red, 3 blue     3 blue, 3 green, 1 red
# 4     Game 5   9 green, 5 red, 10 blue    9 red, 4 blue, 12 green
# ..       ...                       ...                        ...
# 95   Game 96          12 green, 2 blue           11 green, 3 blue
# 96   Game 97    6 red, 3 blue, 1 green    1 blue, 2 red, 14 green
# 97   Game 98   13 green, 1 red, 5 blue     2 red, 5 green, 7 blue
# 98   Game 99           11 red, 8 green           16 red, 10 green
# 99  Game 100    4 red, 2 blue, 4 green     2 green, 1 red, 1 blue
#
#                             3                         4  \
# 0    11 red, 3 blue, 11 green   1 red, 10 green, 4 blue
# 1    10 green, 1 blue, 10 red   7 green, 15 red, 1 blue
# 2     8 blue, 11 red, 2 green    5 red, 9 green, 6 blue
# 3            11 blue, 2 green          2 green, 14 blue
# 4     9 green, 6 blue, 14 red   16 green, 8 red, 6 blue
# ..                        ...                       ...
# 95     3 red, 2 green, 5 blue   12 green, 2 blue, 4 red
# 96           4 blue, 14 green                       NaN
# 97           19 green, 5 blue          4 blue, 13 green
# 98             9 red, 6 green    3 blue, 2 red, 4 green
# 99     3 green, 4 blue, 5 red            18 red, 2 blue
#
#                             5                          6
# 0    17 red, 12 green, 7 blue   3 blue, 19 green, 15 red
# 1     7 green, 8 blue, 16 red    18 red, 5 green, 3 blue
# 2                         NaN                        NaN
# 3             1 green, 7 blue           11 blue, 5 green
# 4    11 blue, 13 red, 1 green                        NaN
# ..                        ...                        ...
# 95     2 blue, 1 green, 1 red    3 red, 11 green, 3 blue
# 96                        NaN                        NaN
# 97            5 green, 8 blue                        NaN
# 98                        NaN                        NaN
# 99     9 red, 5 green, 4 blue                        NaN
#
# [100 rows x 7 columns]

# %%
possibles=[]
for game in range(df.shape[0]):
    red=[]
    blue=[]
    green=[]
    for samples in range(1,6,1):
        if type(df[samples][game])==type('str'):
            sample=df[samples][game]
            sample=sample.split()
            print(sample)
            for i in range(len(sample)-1):
                if sample[i+1]=='green':
                    green.append(int(sample[i]))
                elif sample[i+1]=='blue':
                    blue.append(int(sample[i]))
                elif sample[i+1]=='red':
                    red.append(int(sample[i]))
        else:
            pass
        
    if sum(blue)<=14:
        if sum(red)<=12:
            if sum(green)<=13:
                possibles.append(game)

possibles
# Out:
# ['1', 'blue']
# ['4', 'green,', '5', 'blue']
# ['11', 'red,', '3', 'blue,', '11', 'green']
# ['1', 'red,', '10', 'green,', '4', 'blue']
# ['17', 'red,', '12', 'green,', '7', 'blue']
# ['17', 'red,', '10', 'green']
# ['3', 'blue,', '17', 'red,', '7', 'green']
# ['10', 'green,', '1', 'blue,', '10', 'red']
# ['7', 'green,', '15', 'red,', '1', 'blue']
# ['7', 'green,', '8', 'blue,', '16', 'red']
# ['10', 'blue,', '3', 'green,', '8', 'red']
# ['15', 'green,', '14', 'blue,', '1', 'red']
# ['8', 'blue,', '11', 'red,', '2', 'green']
# ['5', 'red,', '9', 'green,', '6', 'blue']
# ['1', 'red,', '3', 'blue']
# ['3', 'blue,', '3', 'green,', '1', 'red']
# ['11', 'blue,', '2', 'green']
# ['2', 'green,', '14', 'blue']
# ['1', 'green,', '7', 'blue']
# ['9', 'green,', '5', 'red,', '10', 'blue']
# ['9', 'red,', '4', 'blue,', '12', 'green']
# ['9', 'green,', '6', 'blue,', '14', 'red']
# ['16', 'green,', '8', 'red,', '6', 'blue']
# ['11', 'blue,', '13', 'red,', '1', 'green']
# ['1', 'blue,', '2', 'green,', '16', 'red']
# ['1', 'green,', '19', 'red']
# ['1', 'blue']
# ['3', 'blue,', '2', 'red,', '1', 'green']
# ['18', 'red,', '2', 'blue,', '1', 'green']
# ['2', 'blue,', '9', 'red,', '5', 'green']
# ['11', 'blue,', '6', 'green,', '4', 'red']
# ['7', 'red,', '3', 'green,', '5', 'blue']
# ['5', 'green,', '11', 'blue,', '7', 'red']
# ['17', 'blue,', '4', 'red,', '3', 'green']
# ['1', 'green,', '6', 'red,', '4', 'blue']
# ['8', 'green,', '4', 'blue,', '2', 'red']
# ['2', 'blue,', '5', 'green']
# ['1', 'green,', '5', 'blue']
# ['4', 'blue']
# ['2', 'red,', '1', 'blue']
# ['1', 'green,', '12', 'blue']
# ['6', 'red,', '4', 'green']
# ['5', 'green,', '14', 'blue,', '9', 'red']
# ['6', 'red,', '13', 'blue,', '2', 'green']
# ['6', 'red,', '17', 'blue,', '1', 'green']
# ['19', 'green,', '1', 'red']
# ['15', 'red,', '7', 'green']
# ['1', 'blue,', '8', 'red,', '14', 'green']
# ['1', 'blue,', '11', 'green,', '1', 'red']
# ['4', 'red,', '3', 'green,', '12', 'blue']
# ['4', 'green,', '13', 'red']
# ['2', 'green,', '15', 'blue,', '5', 'red']
# ['5', 'red,', '10', 'blue,', '3', 'green']
# ['3', 'green,', '17', 'blue,', '17', 'red']
# ['5', 'red,', '7', 'blue']
# ['6', 'red,', '1', 'green,', '11', 'blue']
# ['17', 'blue,', '11', 'green,', '4', 'red']
# ['6', 'red,', '9', 'green,', '5', 'blue']
# ['4', 'green,', '14', 'blue']
# ['6', 'red,', '15', 'blue,', '3', 'green']
# ['4', 'green,', '4', 'blue,', '3', 'red']
# ['3', 'blue,', '1', 'green,', '5', 'red']
# ['4', 'green,', '3', 'blue,', '6', 'red']
# ['3', 'blue,', '2', 'red,', '4', 'green']
# ['15', 'red,', '3', 'green,', '4', 'blue']
# ['11', 'red,', '2', 'blue,', '1', 'green']
# ['4', 'green,', '1', 'blue,', '12', 'red']
# ['10', 'green,', '6', 'blue,', '10', 'red']
# ['1', 'blue,', '2', 'green,', '15', 'red']
# ['1', 'green,', '3', 'red,', '4', 'blue']
# ['10', 'green,', '11', 'blue']
# ['13', 'green,', '10', 'blue,', '3', 'red']
# ['8', 'red,', '3', 'green,', '10', 'blue']
# ['3', 'red']
# ['4', 'red,', '1', 'blue']
# ['3', 'green,', '3', 'red']
# ['10', 'green,', '1', 'blue']
# ['4', 'red,', '6', 'green,', '1', 'blue']
# ['4', 'red,', '6', 'green']
# ['11', 'red,', '4', 'blue,', '2', 'green']
# ['4', 'green,', '8', 'red']
# ['9', 'red,', '7', 'green,', '2', 'blue']
# ['13', 'red,', '4', 'blue']
# ['2', 'blue,', '1', 'green,', '8', 'red']
# ['3', 'green,', '11', 'blue,', '1', 'red']
# ['5', 'blue,', '4', 'red,', '6', 'green']
# ['6', 'green,', '7', 'red,', '5', 'blue']
# ['7', 'red,', '2', 'green,', '1', 'blue']
# ['7', 'blue,', '3', 'green']
# ['2', 'green,', '2', 'red,', '7', 'blue']
# ['6', 'blue,', '3', 'red,', '1', 'green']
# ['9', 'blue,', '1', 'green,', '3', 'red']
# ['7', 'red,', '5', 'blue,', '9', 'green']
# ['6', 'red,', '1', 'blue,', '5', 'green']
# ['18', 'red,', '7', 'green,', '5', 'blue']
# ['13', 'red,', '11', 'green,', '1', 'blue']
# ['13', 'red,', '1', 'blue,', '11', 'green']
# ['10', 'green,', '1', 'blue,', '5', 'red']
# ['2', 'red,', '4', 'green']
# ['9', 'green,', '2', 'red']
# ['10', 'green,', '1', 'blue,', '5', 'red']
# ['2', 'red,', '6', 'green,', '16', 'blue']
# ['3', 'blue,', '12', 'red,', '3', 'green']
# ['6', 'blue,', '4', 'red,', '12', 'green']
# ['12', 'green,', '14', 'blue,', '3', 'red']
# ['5', 'red,', '2', 'blue,', '1', 'green']
# ['4', 'blue,', '14', 'red,', '2', 'green']
# ['16', 'blue,', '4', 'red']
# ['5', 'red']
# ['12', 'blue,', '16', 'red']
# ['10', 'blue,', '6', 'green,', '5', 'red']
# ['2', 'red,', '2', 'green']
# ['8', 'blue,', '5', 'red']
# ['7', 'blue,', '11', 'green']
# ['8', 'green,', '9', 'blue']
# ['1', 'red,', '2', 'green']
# ['6', 'green,', '10', 'blue']
# ['1', 'red,', '6', 'green,', '11', 'blue']
# ['4', 'blue,', '1', 'green,', '1', 'red']
# ['1', 'red,', '7', 'blue']
# ['6', 'blue,', '5', 'red,', '3', 'green']
# ['5', 'blue,', '1', 'green']
# ['1', 'green,', '8', 'red,', '1', 'blue']
# ['2', 'blue,', '4', 'green']
# ['4', 'red,', '5', 'blue']
# ['2', 'red,', '4', 'green,', '6', 'blue']
# ['6', 'blue,', '2', 'green,', '1', 'red']
# ['10', 'green,', '13', 'blue,', '2', 'red']
# ['11', 'green,', '11', 'blue,', '2', 'red']
# ['5', 'red,', '10', 'green']
# ['4', 'green,', '4', 'blue,', '5', 'red']
# ['6', 'red,', '18', 'green,', '7', 'blue']
# ['1', 'red,', '11', 'green,', '2', 'blue']
# ['11', 'red,', '2', 'blue,', '1', 'green']
# ['1', 'red,', '7', 'green,', '2', 'blue']
# ['5', 'red,', '6', 'green,', '9', 'blue']
# ['3', 'green,', '1', 'red,', '9', 'blue']
# ['3', 'red']
# ['8', 'blue,', '6', 'green,', '1', 'red']
# ['11', 'red,', '2', 'blue,', '2', 'green']
# ['18', 'blue,', '1', 'green']
# ['6', 'blue,', '1', 'green,', '15', 'red']
# ['4', 'red,', '2', 'green']
# ['13', 'red,', '6', 'green,', '5', 'blue']
# ['12', 'blue,', '2', 'red,', '2', 'green']
# ['5', 'blue,', '3', 'green']
# ['2', 'green,', '6', 'red,', '4', 'blue']
# ['12', 'blue,', '13', 'red']
# ['10', 'blue,', '12', 'red,', '1', 'green']
# ['2', 'blue,', '1', 'red,', '6', 'green']
# ['2', 'blue,', '1', 'green']
# ['1', 'red,', '2', 'green,', '2', 'blue']
# ['17', 'red,', '1', 'blue,', '2', 'green']
# ['4', 'green,', '2', 'red']
# ['2', 'blue,', '12', 'red,', '2', 'green']
# ['2', 'green,', '8', 'red,', '11', 'blue']
# ['17', 'red,', '16', 'blue']
# ['8', 'blue,', '8', 'red']
# ['1', 'green,', '6', 'red,', '9', 'blue']
# ['6', 'red,', '14', 'green,', '7', 'blue']
# ['1', 'green,', '1', 'red,', '6', 'blue']
# ['9', 'red,', '10', 'blue,', '9', 'green']
# ['11', 'blue,', '14', 'green,', '8', 'red']
# ['10', 'red,', '6', 'green,', '3', 'blue']
# ['6', 'green']
# ['2', 'red,', '5', 'green']
# ['4', 'blue,', '4', 'red,', '5', 'green']
# ['1', 'red,', '7', 'green,', '4', 'blue']
# ['1', 'green,', '8', 'red,', '10', 'blue']
# ['3', 'green,', '5', 'red,', '12', 'blue']
# ['13', 'blue,', '5', 'red,', '1', 'green']
# ['3', 'green,', '1', 'red']
# ['3', 'red,', '15', 'blue,', '6', 'green']
# ['15', 'green,', '3', 'blue']
# ['3', 'green']
# ['3', 'blue,', '3', 'red,', '8', 'green']
# ['4', 'blue,', '10', 'green,', '4', 'red']
# ['2', 'green,', '5', 'blue,', '4', 'red']
# ['2', 'red,', '3', 'green,', '15', 'blue']
# ['5', 'blue,', '13', 'green,', '2', 'red']
# ['11', 'blue,', '1', 'red']
# ['5', 'blue,', '20', 'green,', '5', 'red']
# ['1', 'red,', '2', 'green,', '1', 'blue']
# ['10', 'red']
# ['11', 'green,', '1', 'blue,', '5', 'red']
# ['10', 'red,', '13', 'green']
# ['10', 'red,', '8', 'green,', '2', 'blue']
# ['5', 'green,', '4', 'red']
# ['6', 'red']
# ['5', 'red,', '9', 'green,', '2', 'blue']
# ['2', 'blue,', '2', 'red,', '3', 'green']
# ['8', 'red,', '6', 'blue,', '12', 'green']
# ['11', 'green,', '2', 'red,', '2', 'blue']
# ['4', 'blue,', '3', 'red,', '8', 'green']
# ['14', 'red,', '3', 'blue']
# ['9', 'green,', '1', 'blue,', '5', 'red']
# ['4', 'red,', '5', 'blue,', '4', 'green']
# ['9', 'blue,', '1', 'green']
# ['10', 'green,', '2', 'blue,', '4', 'red']
# ['5', 'red,', '15', 'green,', '12', 'blue']
# ['1', 'red,', '2', 'green']
# ['5', 'blue']
# ['3', 'blue,', '1', 'red']
# ['1', 'blue']
# ['4', 'green,', '1', 'red']
# ['3', 'green,', '8', 'red,', '5', 'blue']
# ['1', 'blue,', '10', 'red,', '5', 'green']
# ['2', 'green,', '5', 'red,', '3', 'blue']
# ['5', 'green,', '4', 'red,', '13', 'blue']
# ['2', 'green,', '1', 'blue']
# ['2', 'red,', '2', 'green,', '6', 'blue']
# ['1', 'green,', '1', 'red,', '1', 'blue']
# ['2', 'green,', '4', 'blue,', '4', 'red']
# ['2', 'green,', '6', 'blue,', '3', 'red']
# ['4', 'blue,', '1', 'green,', '2', 'red']
# ['6', 'blue,', '1', 'red']
# ['4', 'blue']
# ['16', 'blue,', '18', 'green,', '13', 'red']
# ['7', 'red,', '13', 'blue']
# ['14', 'green,', '12', 'red']
# ['20', 'green,', '14', 'red,', '12', 'blue']
# ['8', 'blue,', '2', 'red,', '1', 'green']
# ['4', 'red,', '2', 'green,', '5', 'blue']
# ['6', 'blue,', '2', 'green']
# ['8', 'blue,', '3', 'green,', '5', 'red']
# ['1', 'green,', '4', 'blue']
# ['2', 'blue,', '8', 'red']
# ['2', 'green,', '3', 'red,', '2', 'blue']
# ['12', 'green']
# ['3', 'blue,', '10', 'green,', '1', 'red']
# ['13', 'green,', '3', 'blue,', '5', 'red']
# ['12', 'blue,', '5', 'red,', '16', 'green']
# ['4', 'blue,', '13', 'green']
# ['2', 'red,', '5', 'blue,', '5', 'green']
# ['4', 'green,', '8', 'blue,', '3', 'red']
# ['7', 'blue,', '5', 'green']
# ['8', 'green,', '8', 'blue']
# ['4', 'red,', '1', 'green']
# ['8', 'blue,', '5', 'red,', '11', 'green']
# ['4', 'blue,', '3', 'green,', '1', 'red']
# ['10', 'green,', '4', 'red,', '7', 'blue']
# ['1', 'red,', '6', 'blue,', '2', 'green']
# ['2', 'red,', '10', 'blue']
# ['13', 'red,', '10', 'blue']
# ['4', 'red,', '5', 'blue,', '4', 'green']
# ['3', 'green,', '8', 'blue']
# ['5', 'blue,', '7', 'red,', '2', 'green']
# ['6', 'green,', '7', 'blue,', '9', 'red']
# ['3', 'blue,', '4', 'green']
# ['15', 'red,', '3', 'blue,', '3', 'green']
# ['5', 'red,', '8', 'green,', '7', 'blue']
# ['9', 'red,', '13', 'blue,', '2', 'green']
# ['3', 'red,', '2', 'green,', '3', 'blue']
# ['1', 'blue,', '5', 'red,', '3', 'green']
# ['9', 'blue,', '2', 'green,', '2', 'red']
# ['3', 'red,', '12', 'blue,', '3', 'green']
# ['4', 'blue,', '7', 'red']
# ['2', 'blue,', '5', 'green,', '1', 'red']
# ['17', 'blue,', '3', 'red']
# ['5', 'green,', '1', 'blue,', '4', 'red']
# ['4', 'green,', '14', 'blue,', '3', 'red']
# ['5', 'blue,', '4', 'red']
# ['7', 'red']
# ['4', 'blue,', '4', 'red,', '1', 'green']
# ['1', 'green,', '1', 'blue,', '5', 'red']
# ['4', 'red,', '2', 'green']
# ['1', 'green,', '2', 'blue']
# ['2', 'red,', '2', 'green']
# ['4', 'red,', '2', 'green']
# ['3', 'red']
# ['6', 'red,', '14', 'green']
# ['12', 'green,', '3', 'blue']
# ['3', 'blue,', '16', 'green,', '11', 'red']
# ['12', 'green,', '2', 'red,', '1', 'blue']
# ['14', 'red,', '2', 'blue,', '4', 'green']
# ['7', 'red,', '5', 'green,', '1', 'blue']
# ['4', 'green,', '14', 'red,', '1', 'blue']
# ['2', 'blue,', '7', 'green,', '3', 'red']
# ['1', 'red,', '8', 'blue,', '12', 'green']
# ['3', 'green,', '10', 'blue,', '4', 'red']
# ['2', 'red,', '1', 'blue,', '2', 'green']
# ['2', 'red,', '8', 'green']
# ['4', 'red,', '3', 'blue,', '9', 'green']
# ['4', 'blue,', '9', 'green,', '4', 'red']
# ['10', 'green,', '6', 'blue,', '7', 'red']
# ['10', 'green,', '8', 'red,', '1', 'blue']
# ['13', 'blue,', '8', 'green,', '8', 'red']
# ['4', 'green,', '1', 'red,', '8', 'blue']
# ['16', 'blue,', '5', 'red,', '13', 'green']
# ['5', 'red,', '9', 'green,', '10', 'blue']
# ['2', 'green,', '14', 'red']
# ['6', 'red,', '5', 'green,', '5', 'blue']
# ['19', 'blue,', '4', 'green,', '14', 'red']
# ['7', 'blue,', '11', 'green,', '5', 'red']
# ['7', 'green,', '8', 'red,', '10', 'blue']
# ['3', 'red,', '1', 'green']
# ['9', 'green,', '2', 'blue,', '13', 'red']
# ['11', 'red,', '10', 'blue']
# ['14', 'red,', '1', 'green,', '1', 'blue']
# ['1', 'red,', '13', 'green,', '6', 'blue']
# ['7', 'blue,', '3', 'green,', '5', 'red']
# ['6', 'green,', '2', 'blue']
# ['1', 'blue,', '3', 'red,', '5', 'green']
# ['1', 'blue,', '10', 'green']
# ['4', 'red,', '6', 'blue,', '1', 'green']
# ['6', 'blue,', '2', 'red,', '4', 'green']
# ['9', 'green,', '7', 'blue,', '2', 'red']
# ['11', 'blue,', '1', 'green,', '4', 'red']
# ['7', 'blue,', '1', 'green']
# ['6', 'red,', '9', 'blue']
# ['1', 'green,', '3', 'red,', '7', 'blue']
# ['1', 'green,', '9', 'blue,', '2', 'red']
# ['2', 'green,', '6', 'red']
# ['1', 'blue,', '2', 'green,', '15', 'red']
# ['6', 'red,', '1', 'blue']
# ['2', 'green,', '5', 'red']
# ['5', 'green,', '6', 'red']
# ['8', 'red,', '1', 'blue,', '12', 'green']
# ['1', 'blue,', '9', 'red,', '15', 'green']
# ['11', 'green,', '1', 'blue,', '6', 'red']
# ['14', 'green,', '5', 'red']
# ['9', 'green,', '13', 'red,', '1', 'blue']
# ['14', 'green,', '5', 'blue,', '13', 'red']
# ['13', 'green,', '10', 'red,', '16', 'blue']
# ['3', 'blue,', '7', 'red,', '1', 'green']
# ['7', 'red,', '6', 'green,', '11', 'blue']
# ['1', 'blue,', '9', 'red,', '15', 'green']
# ['3', 'blue,', '7', 'green']
# ['9', 'green,', '1', 'blue,', '7', 'red']
# ['5', 'blue,', '12', 'red,', '2', 'green']
# ['2', 'blue,', '2', 'green']
# ['4', 'green,', '2', 'red,', '7', 'blue']
# ['4', 'green,', '7', 'blue,', '5', 'red']
# ['1', 'green,', '7', 'blue,', '3', 'red']
# ['1', 'blue']
# ['8', 'red,', '13', 'blue']
# ['4', 'green,', '7', 'blue,', '7', 'red']
# ['3', 'red,', '12', 'blue,', '2', 'green']
# ['2', 'green,', '2', 'blue,', '1', 'red']
# ['4', 'blue']
# ['4', 'blue']
# ['1', 'blue,', '1', 'red']
# ['1', 'red,', '5', 'blue']
# ['10', 'blue,', '1', 'green']
# ['3', 'blue,', '10', 'green,', '6', 'red']
# ['12', 'red,', '7', 'blue,', '8', 'green']
# ['2', 'green,', '18', 'red,', '5', 'blue']
# ['2', 'red,', '15', 'blue,', '14', 'green']
# ['4', 'green,', '6', 'blue,', '13', 'red']
# ['7', 'red,', '1', 'green']
# ['1', 'blue,', '6', 'red,', '2', 'green']
# ['1', 'blue,', '12', 'red']
# ['4', 'red,', '6', 'blue,', '2', 'green']
# ['5', 'blue,', '2', 'red']
# ['6', 'blue,', '7', 'red,', '2', 'green']
# ['2', 'green,', '9', 'red']
# ['2', 'green,', '2', 'blue,', '7', 'red']
# ['12', 'red,', '7', 'green']
# ['8', 'green,', '3', 'red,', '3', 'blue']
# ['4', 'green,', '5', 'blue']
# ['2', 'red,', '16', 'blue']
# ['2', 'red,', '2', 'green,', '18', 'blue']
# ['14', 'red,', '2', 'green']
# ['3', 'blue,', '16', 'red,', '2', 'green']
# ['4', 'green,', '13', 'red,', '1', 'blue']
# ['10', 'green,', '6', 'blue,', '2', 'red']
# ['5', 'red,', '6', 'blue']
# ['7', 'green,', '6', 'red,', '9', 'blue']
# ['1', 'red']
# ['12', 'red,', '1', 'blue,', '2', 'green']
# ['6', 'red,', '1', 'green']
# ['12', 'red,', '2', 'green']
# ['14', 'red,', '1', 'green,', '3', 'blue']
# ['3', 'blue']
# ['4', 'green,', '8', 'red,', '2', 'blue']
# ['10', 'red,', '2', 'green']
# ['4', 'red,', '9', 'green,', '8', 'blue']
# ['3', 'green,', '6', 'blue,', '7', 'red']
# ['4', 'blue,', '1', 'red']
# ['2', 'red,', '7', 'blue,', '11', 'green']
# ['8', 'green,', '2', 'blue,', '5', 'red']
# ['1', 'green,', '1', 'red']
# ['2', 'green,', '1', 'blue']
# ['3', 'green,', '1', 'red,', '1', 'blue']
# ['4', 'green']
# ['1', 'blue,', '3', 'green,', '1', 'red']
# ['11', 'green,', '7', 'blue,', '8', 'red']
# ['7', 'blue,', '3', 'green,', '2', 'red']
# ['7', 'green,', '6', 'red,', '4', 'blue']
# ['1', 'blue,', '2', 'green,', '10', 'red']
# ['3', 'red,', '2', 'blue,', '1', 'green']
# ['10', 'green,', '12', 'red,', '2', 'blue']
# ['7', 'red,', '7', 'blue,', '8', 'green']
# ['2', 'blue,', '11', 'red,', '7', 'green']
# ['6', 'green,', '5', 'red,', '2', 'blue']
# ['7', 'red,', '10', 'green']
# ['12', 'red,', '8', 'green']
# ['8', 'red,', '6', 'green,', '3', 'blue']
# ['12', 'red,', '4', 'blue,', '2', 'green']
# ['10', 'blue,', '3', 'green']
# ['4', 'red,', '13', 'blue,', '8', 'green']
# ['7', 'green,', '8', 'blue,', '7', 'red']
# ['7', 'red,', '4', 'green,', '1', 'blue']
# ['15', 'green,', '4', 'red']
# ['2', 'blue,', '15', 'red']
# ['10', 'red,', '10', 'green,', '11', 'blue']
# ['3', 'red,', '1', 'green,', '7', 'blue']
# ['9', 'red,', '4', 'green,', '9', 'blue']
# ['7', 'red,', '9', 'green,', '13', 'blue']
# ['9', 'blue,', '2', 'green,', '10', 'red']
# ['4', 'blue,', '12', 'green']
# ['7', 'green,', '1', 'red,', '5', 'blue']
# ['2', 'blue,', '8', 'green,', '8', 'red']
# ['12', 'green,', '2', 'blue']
# ['11', 'green,', '3', 'blue']
# ['3', 'red,', '2', 'green,', '5', 'blue']
# ['12', 'green,', '2', 'blue,', '4', 'red']
# ['2', 'blue,', '1', 'green,', '1', 'red']
# ['6', 'red,', '3', 'blue,', '1', 'green']
# ['1', 'blue,', '2', 'red,', '14', 'green']
# ['4', 'blue,', '14', 'green']
# ['13', 'green,', '1', 'red,', '5', 'blue']
# ['2', 'red,', '5', 'green,', '7', 'blue']
# ['19', 'green,', '5', 'blue']
# ['4', 'blue,', '13', 'green']
# ['5', 'green,', '8', 'blue']
# ['11', 'red,', '8', 'green']
# ['16', 'red,', '10', 'green']
# ['9', 'red,', '6', 'green']
# ['3', 'blue,', '2', 'red,', '4', 'green']
# ['4', 'red,', '2', 'blue,', '4', 'green']
# ['2', 'green,', '1', 'red,', '1', 'blue']
# ['3', 'green,', '4', 'blue,', '5', 'red']
# ['18', 'red,', '2', 'blue']
# ['9', 'red,', '5', 'green,', '4', 'blue']
# [2,
#  6,
#  7,
#  8,
#  9,
#  13,
#  14,
#  17,
#  18,
#  19,
#  20,
#  22,
#  25,
#  27,
#  28,
#  29,
#  33,
#  38,
#  41,
#  43,
#  44,
#  46,
#  47,
#  49,
#  53,
#  55,
#  56,
#  59,
#  61,
#  65,
#  68,
#  74,
#  75,
#  76,
#  78,
#  79,
#  82,
#  84,
#  85,
#  87,
#  90,
#  91,
#  94,
#  95,
#  99]

# %%
possibles=[]
for game in range(df.shape[0]):
    
    for samples in range(1,6,1):
        if type(df[samples][game])==type('str'):
            sample=df[samples][game]
            sample=sample.split()
            print(sample)
            for i in range(len(sample)-1):
                if sample[i+1]=='green':
                    green=int(sample[i])
                elif sample[i+1]=='blue':
                    blue=int(sample[i])
                elif sample[i+1]=='red':
                    red=int(sample[i])
                
                if blue<=14 and red<=12 and green<=13:
                possibles.append(game)
        else:
            pass
        

possibles
# Out:
# 1

# %%
type(df[1][1])
# Out:
# str
